# %% [markdown]
# ## Set-up

# %%
# Install Cornac

# !pip install --quiet cornac==1.5.2 adjustText
# Out:
#      |████████████████████████████████| 10.0 MB 4.4 MB/s
#   Building wheel for adjustText (setup.py) ... done

# %%
# Set seed

USE_SEED = True

if USE_SEED:
    SEED = 42
else:
    SEED = None

VERBOSE = True

# %%
# Install libraries

from collections import defaultdict
import cornac
from cornac.utils import cache
from datetime import datetime
import json
import numpy as np
import os
import pandas as pd
from sklearn.model_selection import train_test_split
import sys

# %%
# Set-up Google Drive

COLAB = True

if COLAB:
  from google.colab import drive
  drive.mount('/content/drive')
  path =  "/content/drive/MyDrive/mitb/recommender-systems-cs608/project/"
else:
  path = ""
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/srendle/libfm.git
# !make all -C libfm
# Out:
# Cloning into 'libfm'...
# remote: Enumerating objects: 233, done.
# remote: Total 233 (delta 0), reused 0 (delta 0), pack-reused 233
# Receiving objects: 100% (233/233), 129.46 KiB | 1.75 MiB/s, done.
# Resolving deltas: 100% (112/112), done.
# make: Entering directory '/content/libfm'
# cd src/libfm; make all
# make[1]: Entering directory '/content/libfm/src/libfm'
# g++ -O3 -Wall -c libfm.cpp -o libfm.o
# mkdir -p ../../bin/
# g++ -O3 -Wall libfm.o -o ../../bin/libFM
# g++ -O3 -Wall -c tools/transpose.cpp -o tools/transpose.o
# mkdir -p ../../bin/
# g++ -O3 tools/transpose.o -o ../../bin/transpose
# g++ -O3 -Wall -c tools/convert.cpp -o tools/convert.o
# mkdir -p ../../bin/
# g++ -O3 tools/convert.o -o ../../bin/convert
# make[1]: Leaving directory '/content/libfm/src/libfm'
# make: Leaving directory '/content/libfm'

# %% [markdown]
# ## Load data

# %%
with open(path + "/data/original/wine-info.json") as f:
  wine_info = json.load(f)

# %%
wine_info = pd.DataFrame(wine_info)
wine_info
# Out:
#        wine_id                                           wine_url  \
# 0      1239886  /SG/en/clos-canarelli-corse-figari/w/1239886?y...
# 1      5047087  /SG/en/abel-mendoza-monge-malvasia/w/5047087?y...
# 2        79489  /SG/en/clonakilla-viognier-nouveau/w/79489?yea...
# 3      6857046  /SG/en/nepenthe-the-luminary-shiraz/w/6857046?...
# 4      5422196  /SG/en/basket-range-vineyard-blend/w/5422196?y...
# ...        ...                                                ...
# 44720  1371807  /SG/en/pasos-de-tango-cabernet-sauvignon/w/137...
# 44721    15814  /SG/en/sella-mosca-tanca-farra-alghero/w/15814...
# 44722  1605551  /SG/en/chateau-haut-brisson-la-reserve-saint-e...
# 44723  9640053  /SG/en/witches-falls-wild-ferment-aglianico/w/...
# 44724  2562589              /SG/en/tim-adams-pinot-gris/w/2562589
#
#                                 wine_name              producer  \
# 0                            Corse Figari        Clos Canarelli
# 1                                Malvasía    Abel Mendoza Monge
# 2                        Viognier Nouveau            Clonakilla
# 3                     The Luminary Shiraz              Nepenthe
# 4                          Vineyard Blend          Basket Range
# ...                                   ...                   ...
# 44720                  Cabernet Sauvignon        Pasos de Tango
# 44721                 Tanca Farra Alghero         Sella & Mosca
# 44722  La Réserve Saint-Émilion Grand Cru  Château Haut-Brisson
# 44723              Wild Ferment Aglianico         Witches Falls
# 44724                          Pinot Gris             Tim Adams
#
#                    region_name country_name average_rating nr_ratings  \
# 0                 Corse Figari       France            4.2        216
# 1                        Rioja        Spain            3.9         74
# 2            Canberra District    Australia            3.9         50
# 3           Mount Lofty Ranges    Australia            0.0          1
# 4               Adelaide Hills    Australia            3.8         16
# ...                        ...          ...            ...        ...
# 44720                  Mendoza    Argentina            0.0          9
# 44721                  Alghero        Italy            3.9       1441
# 44722  Saint-Émilion Grand Cru       France            3.9        261
# 44723          South Australia    Australia            3.8         12
# 44724             Clare Valley    Australia            3.9       1205
#
#                                           wine_image_url  \
# 0      //images.vivino.com/thumbs/5s4Unq0rQkumOx9etvh...
# 1      //images.vivino.com/thumbs/wV951FvQTcKDD56rH4f...
# 2      //images.vivino.com/thumbs/022fsiry7i5bo_150x2...
# 3      //images.vivino.com/thumbs/GPm08f-uSRGDk7Pta52...
# 4      //images.vivino.com/thumbs/kSRloTiESjiAgFdFCvS...
# ...                                                  ...
# 44720  //images.vivino.com/thumbs/Ulo2dsz2QTqFqPuhjAr...
# 44721  //images.vivino.com/thumbs/BIzMemGOTE-XrrMKRzi...
# 44722  //images.vivino.com/thumbs/7i9vVv9fRbSIPnnOdf0...
# 44723  //images.vivino.com/thumbs/Vv-JVWAuRuqSJt5psm1...
# 44724  //images.vivino.com/thumbs/YhU_zHg4S2u7IolJUPf...
#
#                                            food_pairings  \
# 0                                                     []
# 1      [Shellfish, Appetizers and snacks, Lean fish, ...
# 2      [Pork, Rich fish (salmon, tuna etc), Spicy foo...
# 3            [Beef, Lamb, Game (deer, venison), Poultry]
# 4      [Beef, Pasta, Lamb, Game (deer, venison), Poul...
# ...                                                  ...
# 44720                                                 []
# 44721                                                 []
# 44722                                                 []
# 44723                                                 []
# 44724                                                 []
#
#                       wine_style
# 0                           None
# 1            Spanish Rioja White
# 2            Australian Viognier
# 3              Australian Shiraz
# 4      Australian Bordeaux Blend
# ...                          ...
# 44720                       None
# 44721                       None
# 44722                       None
# 44723                       None
# 44724                       None
#
# [44725 rows x 11 columns]

# %%
food_info = wine_info.copy()
food_info.drop(['wine_url', 'wine_name', 'producer', 'region_name', 'country_name', 'average_rating', 'nr_ratings', 'wine_image_url', 'wine_style'], axis=1, inplace=True)
food_info.head()
# Out:
#    wine_id                                      food_pairings
# 0  1239886                                                 []
# 1  5047087  [Shellfish, Appetizers and snacks, Lean fish, ...
# 2    79489  [Pork, Rich fish (salmon, tuna etc), Spicy foo...
# 3  6857046        [Beef, Lamb, Game (deer, venison), Poultry]
# 4  5422196  [Beef, Pasta, Lamb, Game (deer, venison), Poul...

# %%
foods = []
for i in range(len(food_info)):
  for j in range(len(food_info.food_pairings[i])):
    if food_info.food_pairings[i][j] not in foods:
      foods.append(food_info.food_pairings[i][j])
foods_df = pd.DataFrame(foods, columns=["food"])
foods_df
ids = pd.DataFrame(list(range(1,len(foods_df)+1)), columns=["id"])
ids
foods_ids = pd.concat([ids, foods_df], axis=1)
foods_ids
# Out:
#     id                          food
# 0    1                     Shellfish
# 1    2         Appetizers and snacks
# 2    3                     Lean fish
# 3    4                    Cured Meat
# 4    5                          Pork
# 5    6  Rich fish (salmon, tuna etc)
# 6    7                    Spicy food
# 7    8                       Poultry
# 8    9                          Beef
# 9   10                          Lamb
# 10  11          Game (deer, venison)
# 11  12                         Pasta
# 12  13                          Veal
# 13  14        Mature and hard cheese
# 14  15          Mild and soft cheese
# 15  16                    Vegetarian
# 16  17                   Goat cheese
# 17  18                     Mushrooms
# 18  19                      Aperitif
# 19  20                   Blue cheese
# 20  21                Sweet desserts
# 21  22               Fruity desserts

# %%
wine_food_pairings = defaultdict(set)
for wine_id, food_pairings, *_ in food_info.itertuples(index=False):
  for i in range(len(food_pairings)):
    food = foods_ids.index[foods_ids["food"]==food_pairings[i]][0]
    wine_food_pairings[wine_id].add(foods_ids["id"][food])

# %%
wine_food_pairings
# Out:
# defaultdict(set,
#             {'5047087': {1, 2, 3, 4},
#              '79489': {5, 6, 7, 8},
#              '6857046': {8, 9, 10, 11},
#              '5422196': {8, 9, 10, 11, 12},
#              '1238219': {9, 10, 11, 12},
#              '1246050': {8, 9, 10, 13},
#              '1776233': {4, 5, 6, 8, 14},
#              '2051324': {1, 4, 6, 12, 15},
#              '1725707': {8, 9, 10, 11},
#              '6200146': {1, 4, 5, 16},
#              '1633327': {9, 12, 13},
#              '1173229': {9, 12, 13},
#              '1222238': {4, 5, 6, 7, 16},
#              '1148247': {1, 16, 17},
#              '93655': {9, 12, 13},
#              '2166006': {8, 9, 11, 13},
#              '1129317': {5, 8, 11, 12, 13},
#              '1689940': {1, 4, 5, 7, 8},
#              '1400098': {8, 9, 10},
#              '76031': {8, 9, 10, 11},
#              '1212457': {8, 9, 12, 13},
#              '63524': {1, 16, 17},
#              '2150072': {8, 9, 10, 11},
#              '1540587': {8, 9, 11, 13},
#              '1174123': {9, 10, 13},
#              '1211648': {8, 9, 11, 13},
#              '4993731': {8, 9, 11, 13},
#              '1888880': {8, 9, 11, 13},
#              '1168825': {9, 12, 13},
#              '1102247': {8, 9, 11, 13},
#              '3622952': {8, 9, 10, 11, 14},
#              '74466': {8, 9, 10, 11},
#              '1226262': {8, 9, 10},
#              '73682': {8, 9, 10, 11, 14},
#              '1164598': {8, 9, 10, 11},
#              '1882309': {8, 9, 10, 11, 14},
#              '1261039': {9, 10, 11, 12},
#              '6995107': {8, 9, 11, 13},
#              '2179092': {8, 9, 10, 11},
#              '9883762': {1, 4, 5, 7, 8},
#              '8468841': {8, 9, 10, 11},
#              '2192937': {9, 10, 11},
#              '8456220': {8, 9, 11, 13},
#              '86337': {9, 10, 11, 12},
#              '6603': {8, 9, 10, 11, 14},
#              '5520': {8, 9, 10, 11, 14},
#              '1232162': {4, 5, 6, 8, 14},
#              '2431421': {8, 9, 10, 11},
#              '4028996': {1, 16, 17},
#              '7097777': {8, 9, 10, 11},
#              '6543456': {9, 10, 11},
#              '1161487': {9, 10, 11},
#              '1671049': {8, 11, 13},
#              '6103764': {8, 9, 11, 13},
#              '1510627': {8, 9, 10, 13},
#              '1473906': {1, 2, 3, 19},
#              '1220142': {1, 2, 3, 19},
#              '1175271': {1, 2, 3, 19},
#              '2484693': {8, 9, 11, 13},
#              '64994': {8, 9, 11, 13},
#              '9269191': {9, 10, 12},
#              '6273702': {5, 8, 9, 11},
#              '1244399': {8, 9, 10, 13},
#              '5758985': {8, 9, 12, 13},
#              '5552260': {8, 9, 12, 13},
#              '9041409': {1, 5, 6, 15},
#              '2389637': {8, 9, 12, 13},
#              '1668538': {8, 9, 13},
#              '1697417': {8, 9, 11, 13},
#              '4122384': {9, 10, 13},
#              '1123136': {8, 9, 11, 13},
#              '2078334': {8, 9, 11, 13},
#              '79475': {8, 9, 11, 13},
#              '5267533': {8, 9, 13},
#              '1190497': {8, 9, 10, 11},
#              '1295959': {1, 5, 6, 15},
#              '5386788': {1, 3, 4, 12, 14},
#              '4131389': {8, 9, 11, 13},
#              '6847598': {5, 6, 8, 16},
#              '1129134': {1, 4, 6, 12, 15},
#              '4401789': {8, 9, 11, 13},
#              '24086': {8, 9, 11, 13},
#              '1683021': {1, 4, 6, 12, 15},
#              '11095': {1, 4, 6, 12, 15},
#              '1957132': {8, 9, 11, 13},
#              '1925467': {1, 4, 6, 12, 15},
#              '10450157': {8, 9, 10},
#              '1864097': {8, 9, 11, 13},
#              '9711': {4, 8, 9, 10, 13},
#              '1511082': {8, 9, 12, 13},
#              '2461866': {4, 12, 16},
#              '9442993': {1, 5, 6, 15},
#              '2131778': {1, 5, 6, 15},
#              '3502264': {1, 2, 16},
#              '1614637': {1, 5, 6, 15},
#              '1310473': {1, 2, 3, 19},
#              '6299925': {3, 8, 12, 16, 19},
#              '9531387': {8, 9, 10, 11},
#              '1583481': {8, 9, 10},
#              '1146200': {5, 8, 12, 13},
#              '14633': {9, 10, 11},
#              '2873168': {1, 2, 4, 16, 19},
#              '2049528': {8, 9, 11, 13},
#              '1221899': {1, 5, 6, 15},
#              '5291159': {3, 4, 5, 8, 16},
#              '1258843': {9, 10, 11, 12},
#              '5371061': {8, 9, 13},
#              '1512889': {9, 10, 11, 12},
#              '2996': {1, 4, 6, 12, 15},
#              '3936299': {4, 8, 9, 10, 13},
#              '3985719': {1, 3},
#              '1823775': {8, 9, 10, 11},
#              '2694817': {8, 9, 10},
#              '1183459': {8, 9, 10},
#              '1128571': {8, 9, 10, 11},
#              '4026015': {8, 9, 10},
#              '18739': {4, 8, 9, 10, 13},
#              '1267521': {8, 9, 10, 11},
#              '1205151': {8, 9, 10, 11},
#              '3969408': {4, 8, 9, 10, 13},
#              '1438643': {9, 10, 11},
#              '1688408': {8, 9, 11, 13},
#              '5847043': {8, 9, 10, 11},
#              '61684': {8, 9, 10, 11},
#              '1141288': {9, 10, 13},
#              '1309273': {9, 10, 11, 20},
#              '9995783': {9, 10, 12},
#              '9767429': {9, 10, 11, 12},
#              '1239692': {8, 9, 13},
#              '3113323': {9, 10, 11, 20},
#              '6500220': {2, 3, 4, 12, 16},
#              '6917951': {9, 10, 12},
#              ...})

# %%
# Load training data

train_ratings_seen = pd.read_csv(path + 'train_test_split/train_ratings_seen.csv')
train_ratings_seen_df = pd.DataFrame(train_ratings_seen, columns=["user_id", "item_id", "rating"])
print(train_ratings_seen_df.shape)
train_ratings_seen_df.head()
# Out:
# (119922, 3)
#     user_id  item_id  rating
# 0  34297304  1260259     4.0
# 1  34297304  1137544     3.0
# 2  34297304  1372673     1.0
# 3  34297304  2511537     3.0
# 4  34297304    92537     4.0

# %%
# Load test data

test_ratings_unseen = pd.read_csv(path + 'train_test_split/test_ratings_unseen.csv')
test_ratings_unseen_df = pd.DataFrame(test_ratings_unseen, columns=["user_id", "item_id", "rating"])
print(test_ratings_unseen_df.shape)
test_ratings_unseen_df.head()
# Out:
# (22492, 3)
#     user_id  item_id  rating
# 0  34297304  1205151     1.0
# 1  34297304    19481     3.0
# 2  34297304  1251093     4.0
# 3  34297304    24169     2.0
# 4  34297304  1221087     2.0

# %%
# Concatenate the data sets
both_df = pd.concat([train_ratings_seen_df, test_ratings_unseen_df], ignore_index=True, axis=0)
print(both_df.shape)
both_df.head()
# Out:
# (142414, 3)
#     user_id  item_id  rating
# 0  34297304  1260259     4.0
# 1  34297304  1137544     3.0
# 2  34297304  1372673     1.0
# 3  34297304  2511537     3.0
# 4  34297304    92537     4.0

# %% [markdown]
# ## Data Statistics

# %%
n_users = train_ratings_seen.user_id.nunique()
n_wines = train_ratings_seen.item_id.nunique()
n_foods = foods_ids.id.nunique()

print("Number of users:", n_users)
print("Number of wines:", n_wines)
print("Number of ratings:", len(train_ratings_seen))
print("Number of foods:", n_foods)
# Out:
# Number of users: 5066
# Number of wines: 39520
# Number of ratings: 119922
# Number of foods: 22

# %% [markdown]
# ## Traditional Matrix Factorization

# %%
eval_method = cornac.eval_methods.BaseMethod.from_splits(
  train_data=list(train_ratings_seen_df.itertuples(index=False)), 
  test_data=list(test_ratings_unseen_df.itertuples(index=False)),
  exclude_unknowns=False, 
  verbose=VERBOSE,
  seed=SEED,
)

mf = cornac.models.MF(
  k=10, 
  max_iter=20, 
  learning_rate=0.01, 
  lambda_reg=0.02, 
  use_bias=True,
  verbose=VERBOSE, seed=SEED,
)

test_result, _ = eval_method.evaluate(
  model=mf, metrics=[cornac.metrics.RMSE()], user_based=False
)
print(test_result)
# Out:
# rating_threshold = 1.0
# exclude_unknowns = False
# ---
# Training data:
# Number of users = 5066
# Number of items = 39520
# Number of ratings = 119922
# Max rating = 5.0
# Min rating = 1.0
# Global mean = 3.9
# ---
# Test data:
# Number of users = 4855
# Number of items = 9900
# Number of ratings = 22492
# Number of unknown users = 0
# Number of unknown items = 0
# ---
# Total users = 5066
# Total items = 39520
#
# [MF] Training started!
#   0%|          | 0/20 [00:00<?, ?it/s]
# Optimization finished!
#
# [MF] Evaluation started!
# Rating:   0%|          | 0/22492 [00:00<?, ?it/s]
#    |   RMSE | Train (s) | Test (s)
# -- + ------ + --------- + --------
# MF | 0.5663 |    0.3026 |   0.5627

# %% [markdown]
# ## Factorization Machines with Contextual Information

# %%
user_id2idx = eval_method.global_uid_map
wine_id2idx = eval_method.global_iid_map

# create mapping for foods
food_id2idx = defaultdict()
for food_id, _ in foods_ids.itertuples(index=False):
  food_id2idx.setdefault(food_id, len(food_id2idx))
assert len(food_id2idx) == n_foods

# %%
def to_fm_sparse_fmt(rating, user_id, wine_id, foods):
  # order of features: user, item, food
  user_start_idx = 0
  wine_start_idx = n_users
  food_start_idx = wine_start_idx + n_wines
  return "{} {}:1 {}:1 {}\n".format(
    rating,
    user_id2idx[user_id],
    wine_id2idx[item_id] + wine_start_idx,
    " ".join("{}:1".format(food_id2idx[t] + food_start_idx) for food in foods)
  )

# save training data to file
with open("train.libfm", "w") as f:
  for user_id, item_id, rating, *_ in train_ratings_seen_df.itertuples(index=False):
    f.write(to_fm_sparse_fmt(rating, user_id, item_id, wine_food_pairings[(item_id)]))

# save test data to file
with open("test.libfm", "w") as f:
  for user_id, item_id, rating, *_ in test_ratings_unseen_df.itertuples(index=False):
    f.write(to_fm_sparse_fmt(rating, user_id, item_id, wine_food_pairings[(item_id)]))

# %%
with open("train.libfm", "r") as f:
  print(f)
# Out:
# <_io.TextIOWrapper name='train.libfm' mode='r' encoding='UTF-8'>

# %%
# !head train.libfm
# Out:
# 4.0 0:1 5066:1
# 3.0 0:1 5067:1
# 1.0 0:1 5068:1
# 3.0 0:1 5069:1
# 4.0 0:1 5070:1
# 3.0 0:1 5071:1
# 4.0 0:1 5072:1
# 4.0 0:1 5073:1
# 3.0 0:1 5074:1
# 3.0 0:1 5075:1

# %%
# !head test.libfm
# Out:
# 1.0 0:1 30835:1
# 3.0 0:1 7055:1
# 4.0 0:1 5978:1
# 2.0 0:1 11559:1
# 2.0 0:1 9328:1
# 2.0 0:1 8549:1
# 3.0 0:1 36345:1
# 3.0 0:1 5197:1
# 4.0 1:1 5212:1
# 3.0 1:1 8516:1

# %%
# !./libfm/bin/libFM
# Out:
# ----------------------------------------------------------------------------
# libFM
#   Version: 1.4.4
#   Author:  Steffen Rendle, srendle@libfm.org
#   WWW:     http://www.libfm.org/
# This program comes with ABSOLUTELY NO WARRANTY; for details see license.txt.
# This is free software, and you are welcome to redistribute it under certain
# conditions; for details see license.txt.
# ----------------------------------------------------------------------------
# -cache_size     cache size for data storage (only applicable if data is
#                 in binary format), default=infty
# -dim            'k0,k1,k2': k0=use bias, k1=use 1-way interactions,
#                 k2=dim of 2-way interactions; default=1,1,8
# -help           this screen
# -init_stdev     stdev for initialization of 2-way factors; default=0.1
# -iter           number of iterations; default=100
# -learn_rate     learn_rate for SGD; default=0.1
# -load_model     filename for reading the FM model
# -meta           filename for meta information about data set
# -method         learning method (SGD, SGDA, ALS, MCMC); default=MCMC
# -out            filename for output
# -regular        'r0,r1,r2' for SGD and ALS: r0=bias regularization,
#                 r1=1-way regularization, r2=2-way regularization
# -relation       BS: filenames for the relations, default=''
# -rlog           write measurements within iterations to a file;
#                 default=''
# -save_model     filename for writing the FM model
# -seed           integer value, default=None
# -task           r=regression, c=binary classification [MANDATORY]
# -test           filename for test data [MANDATORY]
# -train          filename for training data [MANDATORY]
# -validation     filename for validation data (only for SGDA)
# -verbosity      how much infos to print; default=0

# %%
# !./libfm/bin/libFM -task r -train train.libfm -test test.libfm -seed $SEED -dim "1,1,10" -iter 500
# Out:
# ----------------------------------------------------------------------------
# libFM
#   Version: 1.4.4
#   Author:  Steffen Rendle, srendle@libfm.org
#   WWW:     http://www.libfm.org/
# This program comes with ABSOLUTELY NO WARRANTY; for details see license.txt.
# This is free software, and you are welcome to redistribute it under certain
# conditions; for details see license.txt.
# ----------------------------------------------------------------------------
# Loading train...
# has x = 0
# has xt = 1
# num_rows=119922	num_values=239844	num_features=44586	min_target=1	max_target=5
# Loading test...
# has x = 0
# has xt = 1
# num_rows=22492	num_values=44984	num_features=44578	min_target=1	max_target=5
# #relations: 0
# Loading meta data...
# #Iter=  0	Train=0.691464	Test=0.674616
# #Iter=  1	Train=0.613796	Test=0.632259
# #Iter=  2	Train=0.601766	Test=0.617064
# #Iter=  3	Train=0.59441	Test=0.608336
# #Iter=  4	Train=0.588267	Test=0.602389
# #Iter=  5	Train=0.581311	Test=0.597442
# #Iter=  6	Train=0.575853	Test=0.593897
# #Iter=  7	Train=0.570666	Test=0.590994
# #Iter=  8	Train=0.566047	Test=0.588228
# #Iter=  9	Train=0.562541	Test=0.585698
# #Iter= 10	Train=0.558411	Test=0.583764
# #Iter= 11	Train=0.555869	Test=0.581786
# #Iter= 12	Train=0.550858	Test=0.579873
# #Iter= 13	Train=0.548516	Test=0.578306
# #Iter= 14	Train=0.545701	Test=0.576885
# #Iter= 15	Train=0.543174	Test=0.57576
# #Iter= 16	Train=0.543311	Test=0.574765
# #Iter= 17	Train=0.541136	Test=0.57381
# #Iter= 18	Train=0.538906	Test=0.572903
# #Iter= 19	Train=0.536974	Test=0.572047
# #Iter= 20	Train=0.535893	Test=0.571201
# #Iter= 21	Train=0.534741	Test=0.570471
# #Iter= 22	Train=0.534793	Test=0.569956
# #Iter= 23	Train=0.533733	Test=0.569403
# #Iter= 24	Train=0.533533	Test=0.568889
# #Iter= 25	Train=0.533848	Test=0.568464
# #Iter= 26	Train=0.532851	Test=0.568065
# #Iter= 27	Train=0.532876	Test=0.567651
# #Iter= 28	Train=0.533354	Test=0.567388
# #Iter= 29	Train=0.532804	Test=0.567133
# #Iter= 30	Train=0.532676	Test=0.566999
# #Iter= 31	Train=0.532115	Test=0.566754
# #Iter= 32	Train=0.530751	Test=0.566628
# #Iter= 33	Train=0.530548	Test=0.566467
# #Iter= 34	Train=0.5313	Test=0.566308
# #Iter= 35	Train=0.531124	Test=0.56601
# #Iter= 36	Train=0.530453	Test=0.565896
# #Iter= 37	Train=0.531055	Test=0.565717
# #Iter= 38	Train=0.531284	Test=0.56558
# #Iter= 39	Train=0.531007	Test=0.565409
# #Iter= 40	Train=0.530877	Test=0.565235
# #Iter= 41	Train=0.530443	Test=0.565146
# #Iter= 42	Train=0.530319	Test=0.56505
# #Iter= 43	Train=0.529735	Test=0.564958
# #Iter= 44	Train=0.529642	Test=0.564849
# #Iter= 45	Train=0.530801	Test=0.564804
# #Iter= 46	Train=0.531319	Test=0.564698
# #Iter= 47	Train=0.530789	Test=0.564691
# #Iter= 48	Train=0.530382	Test=0.564632
# #Iter= 49	Train=0.530667	Test=0.564546
# #Iter= 50	Train=0.531628	Test=0.564527
# #Iter= 51	Train=0.531011	Test=0.564488
# #Iter= 52	Train=0.531691	Test=0.564436
# #Iter= 53	Train=0.530689	Test=0.564418
# #Iter= 54	Train=0.530296	Test=0.56436
# #Iter= 55	Train=0.530896	Test=0.56436
# #Iter= 56	Train=0.530697	Test=0.564298
# #Iter= 57	Train=0.529347	Test=0.564257
# #Iter= 58	Train=0.530357	Test=0.564244
# #Iter= 59	Train=0.530333	Test=0.564209
# #Iter= 60	Train=0.530556	Test=0.564153
# #Iter= 61	Train=0.530344	Test=0.564183
# #Iter= 62	Train=0.531009	Test=0.564165
# #Iter= 63	Train=0.532106	Test=0.564157
# #Iter= 64	Train=0.531296	Test=0.564165
# #Iter= 65	Train=0.530268	Test=0.564195
# #Iter= 66	Train=0.530595	Test=0.56418
# #Iter= 67	Train=0.530906	Test=0.564172
# #Iter= 68	Train=0.531786	Test=0.564119
# #Iter= 69	Train=0.531877	Test=0.56409
# #Iter= 70	Train=0.53116	Test=0.564039
# #Iter= 71	Train=0.530804	Test=0.563982
# #Iter= 72	Train=0.530765	Test=0.563961
# #Iter= 73	Train=0.530915	Test=0.563928
# #Iter= 74	Train=0.530757	Test=0.563939
# #Iter= 75	Train=0.531789	Test=0.563928
# #Iter= 76	Train=0.531012	Test=0.563925
# #Iter= 77	Train=0.530666	Test=0.563918
# #Iter= 78	Train=0.530349	Test=0.563921
# #Iter= 79	Train=0.530883	Test=0.563889
# #Iter= 80	Train=0.53102	Test=0.563875
# #Iter= 81	Train=0.531225	Test=0.563887
# #Iter= 82	Train=0.530543	Test=0.563901
# #Iter= 83	Train=0.531649	Test=0.56389
# #Iter= 84	Train=0.531825	Test=0.563881
# #Iter= 85	Train=0.531071	Test=0.563857
# #Iter= 86	Train=0.531748	Test=0.563842
# #Iter= 87	Train=0.53128	Test=0.56389
# #Iter= 88	Train=0.530688	Test=0.563897
# #Iter= 89	Train=0.53111	Test=0.563908
# #Iter= 90	Train=0.529846	Test=0.563881
# #Iter= 91	Train=0.530856	Test=0.563884
# #Iter= 92	Train=0.531364	Test=0.563884
# #Iter= 93	Train=0.530287	Test=0.563865
# #Iter= 94	Train=0.529017	Test=0.563846
# #Iter= 95	Train=0.528901	Test=0.563847
# #Iter= 96	Train=0.528512	Test=0.563833
# #Iter= 97	Train=0.529231	Test=0.563824
# #Iter= 98	Train=0.528948	Test=0.56382
# #Iter= 99	Train=0.529226	Test=0.563817
# #Iter=100	Train=0.529864	Test=0.563799
# #Iter=101	Train=0.530133	Test=0.563801
# #Iter=102	Train=0.529302	Test=0.563769
# #Iter=103	Train=0.530312	Test=0.563776
# #Iter=104	Train=0.530027	Test=0.563735
# #Iter=105	Train=0.530412	Test=0.563723
# #Iter=106	Train=0.529459	Test=0.56371
# #Iter=107	Train=0.529729	Test=0.563711
# #Iter=108	Train=0.530224	Test=0.563679
# #Iter=109	Train=0.531034	Test=0.563669
# #Iter=110	Train=0.53137	Test=0.563651
